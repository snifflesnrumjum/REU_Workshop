# %% [markdown]
# # `pandas`!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

import pandas as pd
pd.set_option('max_rows', 6)  # max number of rows to show in this notebook — to save space!

import seaborn as sns  # for better style in plots

plt.style.use('seaborn')

# %% [markdown]
# For 1D analysis, we are generally thinking about data that varies in time, so time series analysis. The `pandas` package is particularly suited to deal with this type of data, having very convenient methods for interpreting, searching through, and using time representations.
#
# Let's look at some recent data from a TABS buoy off the coast of Texas.

# %% [markdown]
# ### If you're running on Google Colab do the following:

# %%
### Only uncomment the following lines if using Google Colab to run this notebook
### uncomment the two lines below here

#from google.colab import drive
#drive.mount('/content/gdrive')  # you'll need to click the link and authorize the notebook to access your Google drive
                                 # then paste the authorization code into the box here; you'll need to use Ctrl+V to paste. 


    
### now go to the file explorer on the right hand side of your Colab notebook and navigate to the folder where your notebook is located
### the path shown below is the path on my Google drive; yours may differ
### uncomment the three lines below here
#your_directory_path = '/content/gdrive/MyDrive/python4geosciences/materials/Module 2'
#import os
#os.chdir(your_directory_path)

# %%
#we can load the data file from the Github page
#Note: we're doing it this way for 2 reasons:
# 1) it avoids having to copy the file to your google drive
# 2) it demonstrates that you can read data files over the internet

df = pd.read_csv('https://raw.githubusercontent.com/snifflesnrumjum/REU_Workshop/73b5c7917846ce3812b058339e372ccda126ad85/TABS_B_data.tsv', header=0, parse_dates=[0], index_col=[0], sep='\t')

# %%
#if file exists on local computer drive:
df = pd.read_csv('./TABS_B_data.tsv', header=0, parse_dates=[0], index_col=[0], sep='\t')

# %%
df
# Out:
#                      East [cm/s]  North [cm/s]  WaterT [deg C]   Tx     Ty  \
# Dates [UTC]
# 2021-05-28 06:00:00          2.2          -5.2            26.6  2.0    0.0
# 2021-05-28 07:00:00          6.2          -7.5            26.6  2.0 -999.0
# 2021-05-28 08:00:00          2.5          -8.9            27.0  2.0    0.0
# ...                          ...           ...             ...  ...    ...
# 2021-06-02 17:00:00         10.4          -6.7            28.0  1.0    0.0
# 2021-06-02 18:00:00         10.9          -7.0            28.1  2.0 -999.0
# 2021-06-02 19:00:00         12.6          -7.7            28.9  1.0    0.0
#
#                      Speed [cm/s]  Across [cm/s]  Along [cm/s]  Dir [deg T]  \
# Dates [UTC]
# 2021-05-28 06:00:00          5.65           5.52         -1.18        157.0
# 2021-05-28 07:00:00          9.73           9.70          0.78        140.0
# 2021-05-28 08:00:00          9.24           8.72         -3.06        164.0
# ...                           ...            ...           ...          ...
# 2021-06-02 17:00:00         12.37          11.45          4.68        123.0
# 2021-06-02 18:00:00         12.95          11.99          4.91        123.0
# 2021-06-02 19:00:00         14.77          13.53          5.90        121.0
#
#                      Cond [ms/cm]  ...  AirT [deg C]  AtmPr [mb]  Gust [m/s]  \
# Dates [UTC]                        ...
# 2021-05-28 06:00:00         44.00  ...          19.8      1037.0        -999
# 2021-05-28 07:00:00         43.15  ...          19.7      1036.0        -999
# 2021-05-28 08:00:00         40.78  ...          19.6      1035.0        -999
# ...                           ...  ...           ...         ...         ...
# 2021-06-02 17:00:00         31.84  ...          22.3      1028.0        -999
# 2021-06-02 18:00:00         31.46  ...          22.9      1023.0        -999
# 2021-06-02 19:00:00         32.20  ...          23.0      1023.0        -999
#
#                      Comp [deg M]  Tx.1  Ty.1  PAR   RelH [%]  Speed [m/s]  \
# Dates [UTC]
# 2021-05-28 06:00:00          26.9  -999  -999  -999      -999          5.4
# 2021-05-28 07:00:00          59.4  -999  -999  -999      -999          5.4
# 2021-05-28 08:00:00          87.4  -999  -999  -999      -999          6.2
# ...                           ...   ...   ...   ...       ...          ...
# 2021-06-02 17:00:00         291.1  -999  -999  -999      -999          2.1
# 2021-06-02 18:00:00         265.3  -999  -999  -999      -999          1.5
# 2021-06-02 19:00:00         275.0  -999  -999  -999      -999          1.2
#
#                      Dir from [deg T]
# Dates [UTC]
# 2021-05-28 06:00:00             139.0
# 2021-05-28 07:00:00             138.0
# 2021-05-28 08:00:00             145.0
# ...                               ...
# 2021-06-02 17:00:00             217.0
# 2021-06-02 18:00:00             192.0
# 2021-06-02 19:00:00             189.0
#
# [129 rows x 25 columns]

# %%
df = df.tz_localize('UTC')

# %% [markdown]
# What do all these (and other) input keyword arguments do?
#
# * header: tells which row of the data file is the header, from which it will extract column names
# * parse_dates: try to interpret the values in `[col]` or `[[col1, col2]]` as dates, to convert them into `datetime` objects.
# * index_col: if no index column is given, an index counting from 0 is given to the rows. By inputting `index_col=[column integer]`, that column will be used as the index instead. This is usually done with the time information for the dataset.
# * skiprows: can skip specific rows, `skiprows=[list of rows to skip numbered from start of file with 0]`, or number of rows to skip, `skiprows=N`.

# %% [markdown]
# We can check to make sure the date/time information has been read in as the index, which allows us to reference the other columns using this time information really easily:

# %%
df.index
# Out:
# DatetimeIndex(['2021-05-28 06:00:00', '2021-05-28 07:00:00',
#                '2021-05-28 08:00:00', '2021-05-28 09:00:00',
#                '2021-05-28 10:00:00', '2021-05-28 11:00:00',
#                '2021-05-28 12:00:00', '2021-05-28 13:00:00',
#                '2021-05-28 14:00:00', '2021-05-28 15:00:00',
#                ...
#                '2021-06-02 09:00:00', '2021-06-02 10:00:00',
#                '2021-06-02 11:00:00', '2021-06-02 12:00:00',
#                '2021-06-02 13:00:00', '2021-06-02 14:00:00',
#                '2021-06-02 15:00:00', '2021-06-02 17:00:00',
#                '2021-06-02 18:00:00', '2021-06-02 19:00:00'],
#               dtype='datetime64[ns]', name='Dates [UTC]', length=129, freq=None)

# %% [markdown]
# From this we see that the index is indeed using the timing information in the file, and we can see that the `dtype` is `datetime`.
#
# We can now access the columns of the file using dictionary-like keyword arguments, like so:

# %%
df['East [cm/s]']
# Out:
# Dates [UTC]
# 2021-05-28 06:00:00     2.2
# 2021-05-28 07:00:00     6.2
# 2021-05-28 08:00:00     2.5
#                        ...
# 2021-06-02 17:00:00    10.4
# 2021-06-02 18:00:00    10.9
# 2021-06-02 19:00:00    12.6
# Name: East [cm/s], Length: 129, dtype: float64

# %% [markdown]
# We can equivalently access the columns of data as if they are methods. This means that we can use tab autocomplete to see methods and data available in a dataframe.
#
# `df.East [cm/s]`
#
# But this won't work for us right now because we have spaces in our column names. Let's rename the columns.

# %%
new_column_names = ['East','North','WaterT','Tx','Ty','Speed','Across','Along','Dir','Cond','Salinity','Density','SoundVel','East_1','North_1','AirT','AtmPr','WindGust','Comp','Tx1','Ty1','PAR','RelH','WindSpeed','WindDir']

# %%
df.columns = new_column_names

# %%
df.East
# Out:
# Dates [UTC]
# 2021-05-28 06:00:00     2.2
# 2021-05-28 07:00:00     6.2
# 2021-05-28 08:00:00     2.5
#                        ...
# 2021-06-02 17:00:00    10.4
# 2021-06-02 18:00:00    10.9
# 2021-06-02 19:00:00    12.6
# Name: East, Length: 129, dtype: float64

# %% [markdown]
# We can plot in this way, too:

# %%
df['East'].plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='Dates [UTC]'>

# %% [markdown]
# ### Simple data selection
#
# One of the biggest benefits of using `pandas` is being able to easily reference the data in intuitive ways. For example, because we set up the index of the dataframe to be the date and time, we can pull out data using dates. In the following, we pull out all data from the first hour of the day:

# %%
df.loc['2021-05-29 01']
# Out:
# East          20.3
# North          3.0
# WaterT        26.6
#              ...
# RelH        -999.0
# WindSpeed      5.7
# WindDir      116.0
# Name: 2021-05-29 01:00:00, Length: 25, dtype: float64

# %% [markdown]
# We can also access a range of data, for example any data rows from midnight until noon:

# %%
df['2021-05-29 00':'2021-05-29 11']
# Out:
#                      East  North  WaterT   Tx     Ty  Speed  Across  Along  \
# Dates [UTC]
# 2021-05-29 01:00:00  20.3    3.0    26.6  3.0    0.0  20.52    9.19  18.35
# 2021-05-29 02:00:00  21.0   -2.2    26.5  1.0 -999.0  21.11   13.85  15.94
# 2021-05-29 03:00:00  22.3   -5.4    26.4  1.0    0.0  22.94   17.21  15.17
# ...                   ...    ...     ...  ...    ...    ...     ...    ...
# 2021-05-29 09:00:00 -17.1  -14.8    26.3  4.0    0.0  22.62    2.32 -22.50
# 2021-05-29 10:00:00 -28.6  -11.7    26.3  2.0 -999.0  30.90   -6.82 -30.14
# 2021-05-29 11:00:00 -34.9   -0.1    26.2  1.0    0.0  34.90  -19.94 -28.65
#
#                        Dir   Cond  ...  AirT   AtmPr  WindGust   Comp  Tx1  \
# Dates [UTC]                        ...
# 2021-05-29 01:00:00   82.0  43.86  ...  20.4  1043.0      -999  359.8 -999
# 2021-05-29 02:00:00   96.0  45.43  ...  20.3  1037.0      -999  355.9 -999
# 2021-05-29 03:00:00  104.0  46.40  ...  20.3  1037.0      -999  350.4 -999
# ...                    ...    ...  ...   ...     ...       ...    ...  ...
# 2021-05-29 09:00:00  229.0  37.19  ...  16.3  1023.0      -999  240.8 -999
# 2021-05-29 10:00:00  248.0  36.71  ...  18.2  1032.0      -999  274.3 -999
# 2021-05-29 11:00:00  270.0  37.16  ...  19.6  1032.0      -999  282.8 -999
#
#                      Ty1  PAR  RelH  WindSpeed  WindDir
# Dates [UTC]
# 2021-05-29 01:00:00 -999 -999  -999       5.70    116.0
# 2021-05-29 02:00:00 -999 -999  -999       3.70    112.0
# 2021-05-29 03:00:00 -999 -999  -999       2.90     99.0
# ...                  ...  ...   ...        ...      ...
# 2021-05-29 09:00:00 -999 -999  -999       6.80     48.0
# 2021-05-29 10:00:00 -999 -999  -999       4.59     71.0
# 2021-05-29 11:00:00 -999 -999  -999       1.90     48.0
#
# [11 rows x 25 columns]

# %% [markdown]
# ### If you want more choice in your selection
#
# The following, adding on minutes, does not work:

# %%
df['2021-05-29 00:30']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\dhenrichs\AppData\Local\Continuum\anaconda3\envs\ocng_669\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021-05-29 00:30'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-be0f80e8da07> in <module>()
# ----> 1 df['2021-05-29 00:30']
#
# C:\Users\dhenrichs\AppData\Local\Continuum\anaconda3\envs\ocng_669\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# C:\Users\dhenrichs\AppData\Local\Continuum\anaconda3\envs\ocng_669\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: '2021-05-29 00:30'

# %%
#If we add an end point it does though
df['2021-05-29 00:30':'2021-05-29 01:00']
# Out:
#                      East  North  WaterT   Tx   Ty  Speed  Across  Along  \
# Dates [UTC]
# 2021-05-29 01:00:00  20.3    3.0    26.6  3.0  0.0  20.52    9.19  18.35
#
#                       Dir   Cond  ...  AirT   AtmPr  WindGust   Comp  Tx1  \
# Dates [UTC]                       ...
# 2021-05-29 01:00:00  82.0  43.86  ...  20.4  1043.0      -999  359.8 -999
#
#                      Ty1  PAR  RelH  WindSpeed  WindDir
# Dates [UTC]
# 2021-05-29 01:00:00 -999 -999  -999        5.7    116.0
#
# [1 rows x 25 columns]

# %% [markdown]
# However, we can use `.loc` to access combinations of specific columns and/or rows, or subsets of columns and/or rows.

# %%
df.loc['2021-05-29 01:00']
# Out:
# East          20.3
# North          3.0
# WaterT        26.6
#              ...
# RelH        -999.0
# WindSpeed      5.7
# WindDir      116.0
# Name: 2021-05-29 01:00:00, Length: 25, dtype: float64

# %% [markdown]
# You can also select data for more specific time periods.
#
# `df.loc[row_label, col_label]`

# %%
df.loc['2021-05-29 01:00', 'East']
# Out:
# 20.3

# %% [markdown]
# You can select more than one column:

# %%
df.loc['2021-05-29 01', ['East','North']]
# Out:
# East     20.3
# North     3.0
# Name: 2021-05-29 01:00:00, dtype: float64

# %% [markdown]
# You can select a range of data:

# %%
df.loc['2021-05-29 00:30':'2021-05-29 05:30', ['East','North']]
# Out:
#                      East  North
# Dates [UTC]
# 2021-05-29 01:00:00  20.3    3.0
# 2021-05-29 02:00:00  21.0   -2.2
# 2021-05-29 03:00:00  22.3   -5.4
# 2021-05-29 04:00:00  21.8   -7.0
# 2021-05-29 05:00:00  14.4   -9.5

# %% [markdown]
# You can alternatively select data by index instead of by label, using `iloc` instead of `loc`. Here we select the first 5 rows of data for all columns:

# %%
df.iloc[0:5, :]
# Out:
#                      East  North  WaterT   Tx     Ty  Speed  Across  Along  \
# Dates [UTC]
# 2021-05-28 06:00:00   2.2   -5.2    26.6  2.0    0.0   5.65    5.52  -1.18
# 2021-05-28 07:00:00   6.2   -7.5    26.6  2.0 -999.0   9.73    9.70   0.78
# 2021-05-28 08:00:00   2.5   -8.9    27.0  2.0    0.0   9.24    8.72  -3.06
# 2021-05-28 09:00:00  -1.3   -5.8    26.9  1.0 -999.0   5.94    4.01  -4.39
# 2021-05-28 10:00:00  -1.0   -5.4    26.9  1.0    0.0   5.49    3.85  -3.92
#
#                        Dir   Cond  ...  AirT   AtmPr  WindGust   Comp  Tx1  \
# Dates [UTC]                        ...
# 2021-05-28 06:00:00  157.0  44.00  ...  19.8  1037.0      -999   26.9 -999
# 2021-05-28 07:00:00  140.0  43.15  ...  19.7  1036.0      -999   59.4 -999
# 2021-05-28 08:00:00  164.0  40.78  ...  19.6  1035.0      -999   87.4 -999
# 2021-05-28 09:00:00  193.0  32.09  ...  19.7  1036.0      -999   98.3 -999
# 2021-05-28 10:00:00  190.0  31.39  ...  19.8  1036.0      -999  107.3 -999
#
#                      Ty1  PAR  RelH  WindSpeed  WindDir
# Dates [UTC]
# 2021-05-28 06:00:00 -999 -999  -999        5.4    139.0
# 2021-05-28 07:00:00 -999 -999  -999        5.4    138.0
# 2021-05-28 08:00:00 -999 -999  -999        6.2    145.0
# 2021-05-28 09:00:00 -999 -999  -999        5.3    159.0
# 2021-05-28 10:00:00 -999 -999  -999        4.8    153.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Adding column to dataframe
#
# We can add data to our dataframe very easily. Below we add an index that gives the minute in the hour throughout the day.

# %%
df['hour'] = df.index.hour # adding a field for the minute of the hour
df['hour'].plot()
# Out:
# <AxesSubplot:xlabel='Dates [UTC]'>

# %% [markdown]
# You can get many different measures of your time index.

# %%
df.index.dayofweek
# Out:
# Int64Index([4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#             ...
#             2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#            dtype='int64', name='Dates [UTC]', length=129)

# %% [markdown]
# ## `groupby`
#
# `groupby` allows us to aggregate data across a category or value. We'll use the example of grouping across a measure of time.
#
# We will use the values from the key `minute` to compute the average of properties over all of the hours in the file, by minute. We access the data in the dataframe, `groupby` the minute of the hour (spanning all of the hours), and then compute the mean.
#
# Note that we can change many `matplotlib` `plot` parameters directly from `pandas`.

# %%
df.groupby(df['hour']).aggregate(np.mean)['WaterT'].plot(color='k', grid=True, figsize=(14, 4), lw=3)
# Out:
# <AxesSubplot:xlabel='hour'>

# %% [markdown]
# For this dataset, this isn't necessarily a very meaningful computation since why would one part of the hour consistently have different types of taxi rides?

# %% [markdown]
# ### Plotting with `pandas`
#
# You can plot with `matplotlib` and control many things directly from `pandas`, such as in the above example.

# %%
df.plot?

# %% [markdown]
# You can select which data columns to plot either by selecting in the line before the `plot` call, or you can choose the columns within the plot call.

# %%
df['East'].plot(figsize=(14,6))
plt.ylabel('Velocity cm$^.$s$^{-1}$', size=20)
plt.title('East Current Velocity', size= 30)
# Out:
# Text(0.5, 1.0, 'East Current Velocity')

# %% [markdown]
# You can also use `matplotlib` directly by pulling the data you want to plot out of your dataframe.

# %%
plt.plot(df.index, df['East'].values)

# %% [markdown]
# ## Resampling
#
# Sometimes we want our data to be at a different sampling frequency that we have, that is, we want to change the time between rows or observations. Changing this is called resampling. We can upsample to increase the number of data points in a given dataset (or decrease the period between points) or we can downsample to decrease the number of data points.
#
# The wind data is given every hour. Here we downsample it to be once a day instead. After the `resample` function, a method needs to be used for how to combine the data over the downsampling period since the existing data needs to be combined in some way. We could use the max value over the 1-day period to represent each day:

# %%
df.resample('1d').max()    # now the data is daily
# Out:
#              East  North  WaterT   Tx   Ty  Speed  Across  Along    Dir  \
# Dates [UTC]
# 2021-05-28   13.5    3.3    27.4  8.0  0.0  17.75   17.42   7.85  270.0
# 2021-05-29   22.3   13.8    28.2  5.0  0.0  34.90   18.24  18.35  345.0
# 2021-05-30   30.1    7.9    27.1  6.0  0.0  30.15   18.66  23.68  330.0
# 2021-05-31   32.2   -4.9    26.6  7.0  0.0  35.96   31.58  20.79  147.0
# 2021-06-01   23.8    9.2    26.9  4.0  0.0  26.43   24.03  18.86  200.0
# 2021-06-02   12.6    0.5    28.9  4.0  0.0  15.01   14.41   9.95  145.0
#
#               Cond  ...   AtmPr  WindGust   Comp  Tx1  Ty1  PAR  RelH  \
# Dates [UTC]         ...
# 2021-05-28   44.00  ...  1050.0      -999  357.0 -999 -999 -999  -999
# 2021-05-29   46.65  ...  1052.0      -999  359.8 -999 -999 -999  -999
# 2021-05-30   48.89  ...  1045.0      -999  358.0 -999 -999 -999  -999
# 2021-05-31   51.73  ...  1034.0      -999  345.9 -999 -999 -999  -999
# 2021-06-01   46.44  ...  1029.0      -999  329.8 -999 -999 -999  -999
# 2021-06-02   42.44  ...  1032.0      -999  336.7 -999 -999 -999  -999
#
#              WindSpeed  WindDir  hour
# Dates [UTC]
# 2021-05-28         7.9    159.0    23
# 2021-05-29        10.0    264.0    23
# 2021-05-30         8.3    175.0    23
# 2021-05-31         6.9    106.0    23
# 2021-06-01         7.4    242.0    23
# 2021-06-02         3.8    217.0    19
#
# [6 rows x 26 columns]

# %% [markdown]
# It's always important to check our results to make sure they look reasonable. Let's plot our resampled data with the original data to make sure they align well. We'll choose one variable for this check.
#
# We can see that the daily max wind gust does indeed look like the max value for each day, though note that it is plotted at the start of the day.

# %%
df['East']['2021-05-28':'2021-05-31'].plot()
df.resample('1d').max()['East']['2021-05-28':'2021-05-31'].plot()
#df.resample('1d').mean()['East']['2021-05-28':'2021-05-31'].plot()
#df.resample('6h').max()['East']['2021-05-28':'2021-05-31'].plot()
# Out:
# <AxesSubplot:xlabel='Dates [UTC]'>

# %% [markdown]
# We can also upsample our data or add more rows of data. Note that like before, after we resample our data we still need a method on the end telling `pandas` how to process the data. However, since in this case we are not combining data (downsampling) but are adding more rows (upsampling), using a function like `max` doesn't change the existing observations (taking the max of a single row). For the new rows, we haven't said how to fill them so they are nan's by default.
#
# Here we are changing from having data every hour to having it every 30 minutes.

# %%
df.resample('30min').max()  # max doesn't say what to do with data in new rows
# Out:
#                      East  North  WaterT   Tx     Ty  Speed  Across  Along  \
# Dates [UTC]
# 2021-05-28 06:00:00   2.2   -5.2    26.6  2.0    0.0   5.65    5.52  -1.18
# 2021-05-28 06:30:00   NaN    NaN     NaN  NaN    NaN    NaN     NaN    NaN
# 2021-05-28 07:00:00   6.2   -7.5    26.6  2.0 -999.0   9.73    9.70   0.78
# ...                   ...    ...     ...  ...    ...    ...     ...    ...
# 2021-06-02 18:00:00  10.9   -7.0    28.1  2.0 -999.0  12.95   11.99   4.91
# 2021-06-02 18:30:00   NaN    NaN     NaN  NaN    NaN    NaN     NaN    NaN
# 2021-06-02 19:00:00  12.6   -7.7    28.9  1.0    0.0  14.77   13.53   5.90
#
#                        Dir   Cond  ...   AtmPr  WindGust   Comp    Tx1    Ty1  \
# Dates [UTC]                        ...
# 2021-05-28 06:00:00  157.0  44.00  ...  1037.0    -999.0   26.9 -999.0 -999.0
# 2021-05-28 06:30:00    NaN    NaN  ...     NaN       NaN    NaN    NaN    NaN
# 2021-05-28 07:00:00  140.0  43.15  ...  1036.0    -999.0   59.4 -999.0 -999.0
# ...                    ...    ...  ...     ...       ...    ...    ...    ...
# 2021-06-02 18:00:00  123.0  31.46  ...  1023.0    -999.0  265.3 -999.0 -999.0
# 2021-06-02 18:30:00    NaN    NaN  ...     NaN       NaN    NaN    NaN    NaN
# 2021-06-02 19:00:00  121.0  32.20  ...  1023.0    -999.0  275.0 -999.0 -999.0
#
#                        PAR   RelH  WindSpeed  WindDir  hour
# Dates [UTC]
# 2021-05-28 06:00:00 -999.0 -999.0        5.4    139.0   6.0
# 2021-05-28 06:30:00    NaN    NaN        NaN      NaN   NaN
# 2021-05-28 07:00:00 -999.0 -999.0        5.4    138.0   7.0
# ...                    ...    ...        ...      ...   ...
# 2021-06-02 18:00:00 -999.0 -999.0        1.5    192.0  18.0
# 2021-06-02 18:30:00    NaN    NaN        NaN      NaN   NaN
# 2021-06-02 19:00:00 -999.0 -999.0        1.2    189.0  19.0
#
# [267 rows x 26 columns]

# %% [markdown]
# When upsampling, a reasonable option is to fill the new rows with data from the previous existing row:

# %%
df.resample('30min').ffill()
# Out:
#                      East  North  WaterT   Tx     Ty  Speed  Across  Along  \
# Dates [UTC]
# 2021-05-28 06:00:00   2.2   -5.2    26.6  2.0    0.0   5.65    5.52  -1.18
# 2021-05-28 06:30:00   2.2   -5.2    26.6  2.0    0.0   5.65    5.52  -1.18
# 2021-05-28 07:00:00   6.2   -7.5    26.6  2.0 -999.0   9.73    9.70   0.78
# ...                   ...    ...     ...  ...    ...    ...     ...    ...
# 2021-06-02 18:00:00  10.9   -7.0    28.1  2.0 -999.0  12.95   11.99   4.91
# 2021-06-02 18:30:00  10.9   -7.0    28.1  2.0 -999.0  12.95   11.99   4.91
# 2021-06-02 19:00:00  12.6   -7.7    28.9  1.0    0.0  14.77   13.53   5.90
#
#                        Dir   Cond  ...   AtmPr  WindGust   Comp  Tx1  Ty1  \
# Dates [UTC]                        ...
# 2021-05-28 06:00:00  157.0  44.00  ...  1037.0      -999   26.9 -999 -999
# 2021-05-28 06:30:00  157.0  44.00  ...  1037.0      -999   26.9 -999 -999
# 2021-05-28 07:00:00  140.0  43.15  ...  1036.0      -999   59.4 -999 -999
# ...                    ...    ...  ...     ...       ...    ...  ...  ...
# 2021-06-02 18:00:00  123.0  31.46  ...  1023.0      -999  265.3 -999 -999
# 2021-06-02 18:30:00  123.0  31.46  ...  1023.0      -999  265.3 -999 -999
# 2021-06-02 19:00:00  121.0  32.20  ...  1023.0      -999  275.0 -999 -999
#
#                      PAR  RelH  WindSpeed  WindDir  hour
# Dates [UTC]
# 2021-05-28 06:00:00 -999  -999        5.4    139.0     6
# 2021-05-28 06:30:00 -999  -999        5.4    139.0     6
# 2021-05-28 07:00:00 -999  -999        5.4    138.0     7
# ...                  ...   ...        ...      ...   ...
# 2021-06-02 18:00:00 -999  -999        1.5    192.0    18
# 2021-06-02 18:30:00 -999  -999        1.5    192.0    18
# 2021-06-02 19:00:00 -999  -999        1.2    189.0    19
#
# [267 rows x 26 columns]

# %% [markdown]
# Here we upsample to have data every 15 minutes, but we interpolate to fill in the data between. This is a very useful thing to be able to do.

# %%
df.resample('15 T').interpolate()
# Out:
#                        East  North  WaterT    Tx      Ty   Speed  Across  \
# Dates [UTC]
# 2021-05-28 06:00:00   2.200 -5.200    26.6  2.00    0.00   5.650   5.520
# 2021-05-28 06:15:00   3.200 -5.775    26.6  2.00 -249.75   6.670   6.565
# 2021-05-28 06:30:00   4.200 -6.350    26.6  2.00 -499.50   7.690   7.610
# ...                     ...    ...     ...   ...     ...     ...     ...
# 2021-06-02 18:30:00  11.750 -7.350    28.5  1.50 -499.50  13.860  12.760
# 2021-06-02 18:45:00  12.175 -7.525    28.7  1.25 -249.75  14.315  13.145
# 2021-06-02 19:00:00  12.600 -7.700    28.9  1.00    0.00  14.770  13.530
#
#                       Along     Dir     Cond  ...    AtmPr  WindGust     Comp  \
# Dates [UTC]                                   ...
# 2021-05-28 06:00:00 -1.1800  157.00  44.0000  ...  1037.00    -999.0   26.900
# 2021-05-28 06:15:00 -0.6900  152.75  43.7875  ...  1036.75    -999.0   35.025
# 2021-05-28 06:30:00 -0.2000  148.50  43.5750  ...  1036.50    -999.0   43.150
# ...                     ...     ...      ...  ...      ...       ...      ...
# 2021-06-02 18:30:00  5.4050  122.00  31.8300  ...  1023.00    -999.0  270.150
# 2021-06-02 18:45:00  5.6525  121.50  32.0150  ...  1023.00    -999.0  272.575
# 2021-06-02 19:00:00  5.9000  121.00  32.2000  ...  1023.00    -999.0  275.000
#
#                        Tx1    Ty1    PAR   RelH  WindSpeed  WindDir   hour
# Dates [UTC]
# 2021-05-28 06:00:00 -999.0 -999.0 -999.0 -999.0      5.400   139.00   6.00
# 2021-05-28 06:15:00 -999.0 -999.0 -999.0 -999.0      5.400   138.75   6.25
# 2021-05-28 06:30:00 -999.0 -999.0 -999.0 -999.0      5.400   138.50   6.50
# ...                    ...    ...    ...    ...        ...      ...    ...
# 2021-06-02 18:30:00 -999.0 -999.0 -999.0 -999.0      1.350   190.50  18.50
# 2021-06-02 18:45:00 -999.0 -999.0 -999.0 -999.0      1.275   189.75  18.75
# 2021-06-02 19:00:00 -999.0 -999.0 -999.0 -999.0      1.200   189.00  19.00
#
# [533 rows x 26 columns]

# %% [markdown]
# The codes for time period/frequency are [available](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases) and are presented here for convenience:
#
#     Alias	Description
#     B	business day frequency
#     C	custom business day frequency (experimental)
#     D	calendar day frequency
#     W	weekly frequency
#     M	month end frequency
#     SM	semi-month end frequency (15th and end of month)
#     BM	business month end frequency
#     CBM	custom business month end frequency
#     MS	month start frequency
#     SMS	semi-month start frequency (1st and 15th)
#     BMS	business month start frequency
#     CBMS	custom business month start frequency
#     Q	quarter end frequency
#     BQ	business quarter endfrequency
#     QS	quarter start frequency
#     BQS	business quarter start frequency
#     A	year end frequency
#     BA	business year end frequency
#     AS	year start frequency
#     BAS	business year start frequency
#     BH	business hour frequency
#     H	hourly frequency
#     T, min	minutely frequency
#     S	secondly frequency
#     L, ms	milliseconds
#     U, us	microseconds
#     N	nanoseconds

# %%
#Show maps
